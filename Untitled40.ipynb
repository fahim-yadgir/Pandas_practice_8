# %%
import pandas as pd

# %%
df = pd.read_csv("Data for sql and python.csv")

# %%
df
# Out:
#      Customer ID   Customer Name   Age Gender       City  Product ID  \
# 0      CUST00001     Rohan Patel  43.0  Other     Mumbai          64
# 1      CUST00002    Simran Reddy  20.0   Male    Kolkata        1031
# 2      CUST00003      Ayaan Iyer  55.0   Male    Lucknow         939
# 3      CUST00004    Anika Chopra  27.0  Other      Delhi         365
# 4      CUST00005     Pooja Singh  53.0  Other      Delhi         613
# ...          ...             ...   ...    ...        ...         ...
# 1195   CUST01196  Krishna Sharma  53.0  Other  Bengaluru         140
# 1196   CUST01197      Amit Singh  53.0  Other      Surat        1019
# 1197   CUST01198      Yash Joshi  49.0   Male     Jaipur         638
# 1198   CUST01199   Vivaan Sharma  45.0  Other       Pune         141
# 1199   CUST01200     Meera Reddy  27.0   Male      Delhi         654
#
#                          Product Name         Brand   Shopping App  Quantity  \
# ...

# %%
df.shape
# Out:
# (1200, 16)

# %%
df.info
# Out:
# <bound method DataFrame.info of      Customer ID   Customer Name   Age Gender       City  Product ID  \
# 0      CUST00001     Rohan Patel  43.0  Other     Mumbai          64
# 1      CUST00002    Simran Reddy  20.0   Male    Kolkata        1031
# 2      CUST00003      Ayaan Iyer  55.0   Male    Lucknow         939
# 3      CUST00004    Anika Chopra  27.0  Other      Delhi         365
# 4      CUST00005     Pooja Singh  53.0  Other      Delhi         613
# ...          ...             ...   ...    ...        ...         ...
# 1195   CUST01196  Krishna Sharma  53.0  Other  Bengaluru         140
# 1196   CUST01197      Amit Singh  53.0  Other      Surat        1019
# 1197   CUST01198      Yash Joshi  49.0   Male     Jaipur         638
# 1198   CUST01199   Vivaan Sharma  45.0  Other       Pune         141
# 1199   CUST01200     Meera Reddy  27.0   Male      Delhi         654
#
#                          Product Name         Brand   Shopping App  Quantity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         1200 non-null   object
#  1   Customer Name       1200 non-null   object
#  2   Age                 1200 non-null   float64
#  3   Gender              1200 non-null   object
#  4   City                1200 non-null   object
#  5   Product ID          1200 non-null   int64
#  6   Product Name        1200 non-null   object
#  7   Brand               1200 non-null   object
#  8   Shopping App        1200 non-null   object
#  9   Quantity            1200 non-null   int64
#  10  Unit Selling Price  1200 non-null   float64
#  11  Total Amount Paid   1200 non-null   float64
#  12  Purchase Date       1200 non-null   object
#  13  Payment Method      1200 non-null   object
#  14  Order Status        1200 non-null   object
# ...

# %%
df.head()
# Out:
#   Customer ID Customer Name   Age Gender     City  Product ID  \
# 0   CUST00001   Rohan Patel  43.0  Other   Mumbai          64
# 1   CUST00002  Simran Reddy  20.0   Male  Kolkata        1031
# 2   CUST00003    Ayaan Iyer  55.0   Male  Lucknow         939
# 3   CUST00004  Anika Chopra  27.0  Other    Delhi         365
# 4   CUST00005   Pooja Singh  53.0  Other    Delhi         613
#
#                      Product Name        Brand   Shopping App  Quantity  \
# 0           H&M Women Solid Kurta          H&M           Ajio         1
# 1       Nike Unisex Ripped Jacket         Nike       Flipkart         1
# 2  Allen Solly Kids Ripped Hoodie  Allen Solly  Nykaa Fashion         1
# 3     Biba Kids Solid Track Pants         Biba       Snapdeal         1
# 4        Levi's Kids Cotton Kurta       Levi's         Meesho         1
#
#    Unit Selling Price  Total Amount Paid Purchase Date    Payment Method  \
# 0             486.115             486.12    07-04-2025        Debit Card
# ...

# %%
df.tail()
# Out:
#      Customer ID   Customer Name   Age Gender       City  Product ID  \
# 1195   CUST01196  Krishna Sharma  53.0  Other  Bengaluru         140
# 1196   CUST01197      Amit Singh  53.0  Other      Surat        1019
# 1197   CUST01198      Yash Joshi  49.0   Male     Jaipur         638
# 1198   CUST01199   Vivaan Sharma  45.0  Other       Pune         141
# 1199   CUST01200     Meera Reddy  27.0   Male      Delhi         654
#
#                          Product Name         Brand   Shopping App  Quantity  \
# 1195          Gap Unisex Formal Skirt           Gap         Myntra         3
# 1196  Under Armour Men Classic Shorts  Under Armour       Flipkart         2
# 1197       Roadster Men Formal Blazer      Roadster  Nykaa Fashion         1
# 1198    Van Heusen Women Cotton Jeans    Van Heusen         Myntra         1
# 1199       Forever 21 Men Solid Kurta    Forever 21         Meesho         1
#
#       Unit Selling Price  Total Amount Paid Purchase Date Payment Method  \
# ...

# %%
df.isna().sum()
# Out:
# Customer ID             0
# Customer Name           0
# Age                     0
# Gender                  0
# City                    0
# Product ID              0
# Product Name            0
# Brand                   0
# Shopping App            0
# Quantity                0
# Unit Selling Price      0
# Total Amount Paid       0
# Purchase Date           0
# Payment Method          0
# Order Status            0
# Customer Rating       118
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#      Customer ID   Customer Name   Age Gender       City  Product ID  \
# 0      CUST00001     Rohan Patel  43.0  Other     Mumbai          64
# 1      CUST00002    Simran Reddy  20.0   Male    Kolkata        1031
# 2      CUST00003      Ayaan Iyer  55.0   Male    Lucknow         939
# 3      CUST00004    Anika Chopra  27.0  Other      Delhi         365
# 4      CUST00005     Pooja Singh  53.0  Other      Delhi         613
# ...          ...             ...   ...    ...        ...         ...
# 1195   CUST01196  Krishna Sharma  53.0  Other  Bengaluru         140
# 1196   CUST01197      Amit Singh  53.0  Other      Surat        1019
# 1197   CUST01198      Yash Joshi  49.0   Male     Jaipur         638
# 1198   CUST01199   Vivaan Sharma  45.0  Other       Pune         141
# 1199   CUST01200     Meera Reddy  27.0   Male      Delhi         654
#
#                          Product Name         Brand   Shopping App  Quantity  \
# ...

# %%
df.fillna(0)
# Out:
#      Customer ID   Customer Name   Age Gender       City  Product ID  \
# 0      CUST00001     Rohan Patel  43.0  Other     Mumbai          64
# 1      CUST00002    Simran Reddy  20.0   Male    Kolkata        1031
# 2      CUST00003      Ayaan Iyer  55.0   Male    Lucknow         939
# 3      CUST00004    Anika Chopra  27.0  Other      Delhi         365
# 4      CUST00005     Pooja Singh  53.0  Other      Delhi         613
# ...          ...             ...   ...    ...        ...         ...
# 1195   CUST01196  Krishna Sharma  53.0  Other  Bengaluru         140
# 1196   CUST01197      Amit Singh  53.0  Other      Surat        1019
# 1197   CUST01198      Yash Joshi  49.0   Male     Jaipur         638
# 1198   CUST01199   Vivaan Sharma  45.0  Other       Pune         141
# 1199   CUST01200     Meera Reddy  27.0   Male      Delhi         654
#
#                          Product Name         Brand   Shopping App  Quantity  \
# ...

# %%
df.describe()
# Out:
#                Age   Product ID     Quantity  Unit Selling Price  \
# count  1200.000000  1200.000000  1200.000000         1200.000000
# mean     36.941667   532.383333     1.239167          696.598893
# std      10.891148   324.361344     0.490408          819.282316
# min      18.000000     2.000000     1.000000          160.588000
# 25%      28.000000   259.000000     1.000000          320.040000
# 50%      37.000000   492.500000     1.000000          397.968000
# 75%      47.000000   790.000000     1.000000          473.444250
# max      55.000000  1194.000000     3.000000         4653.150000
#
#        Total Amount Paid  Customer Rating
# count        1200.000000      1082.000000
# mean          968.854200         3.575786
# std          1472.092571         1.431858
# min           160.590000         1.000000
# 25%           345.150000         2.000000
# 50%           411.650000         4.000000
# 75%           760.822500         5.000000
# ...

# %%
df[df["Age"]==45].count()
# Out:
# Customer ID           27
# Customer Name         27
# Age                   27
# Gender                27
# City                  27
# Product ID            27
# Product Name          27
# Brand                 27
# Shopping App          27
# Quantity              27
# Unit Selling Price    27
# Total Amount Paid     27
# Purchase Date         27
# Payment Method        27
# Order Status          27
# Customer Rating       24
# dtype: int64

# %%
df[df["City"]=="Pune"].count()
# Out:
# Customer ID           73
# Customer Name         73
# Age                   73
# Gender                73
# City                  73
# Product ID            73
# Product Name          73
# Brand                 73
# Shopping App          73
# Quantity              73
# Unit Selling Price    73
# Total Amount Paid     73
# Purchase Date         73
# Payment Method        73
# Order Status          73
# Customer Rating       67
# dtype: int64

# %%
df[df["Gender"]=="Female"].count()
# Out:
# Customer ID           386
# Customer Name         386
# Age                   386
# Gender                386
# City                  386
# Product ID            386
# Product Name          386
# Brand                 386
# Shopping App          386
# Quantity              386
# Unit Selling Price    386
# Total Amount Paid     386
# Purchase Date         386
# Payment Method        386
# Order Status          386
# Customer Rating       352
# dtype: int64

# %%
df.groupby("Gender")["Customer Rating"]

# %%
df[(df["Age"]>5) & (df["Total Amount Paid"]>=4500)].max()
# Out:
# Customer ID                           CUST01196
# Customer Name                        Yash Singh
# Age                                        55.0
# Gender                                    Other
# City                                      Surat
# Product ID                                 1194
# Product Name          Zara Women Solid Trousers
# Brand                                      Zara
# Shopping App                          Tata CLiQ
# Quantity                                      3
# Unit Selling Price                      4653.15
# Total Amount Paid                      10745.92
# Purchase Date                        31-01-2025
# Payment Method                           Wallet
# Order Status                            Shipped
# Customer Rating                             5.0
# dtype: object

# %%
df[df["Customer Name"]=="Yash Singh"]
# Out:
#      Customer ID Customer Name   Age  Gender        City  Product ID  \
# 534    CUST00535    Yash Singh  22.0  Female   Bengaluru          85
# 1191   CUST01192    Yash Singh  54.0   Other  Chandigarh         284
#
#                        Product Name     Brand Shopping App  Quantity  \
# 534   Roadster Unisex Striped Shirt  Roadster     Snapdeal         2
# 1191          W Women Striped Kurta         W       Meesho         1
#
#       Unit Selling Price  Total Amount Paid Purchase Date Payment Method  \
# 534              2990.10            5980.20    21-02-2026    Credit Card
# 1191             1793.66            1793.66    18-09-2025         Wallet
#
#      Order Status  Customer Rating
# 534     Delivered              3.0
# 1191    Cancelled              4.0

# %%
df.groupby("Gender")["Age"].mean()
# Out:
# Gender
# Female    37.012953
# Male      36.761337
# Other     37.063291
# Name: Age, dtype: float64

# %%
df.groupby("Gender")["Age"].min()
# Out:
# Gender
# Female    18.0
# Male      18.0
# Other     18.0
# Name: Age, dtype: float64

# %%
df.groupby("Brand")["Age"].min()
# Out:
# Brand
# Adidas            18.0
# Allen Solly       18.0
# Biba              19.0
# Calvin Klein      18.0
# Forever 21        18.0
# Gap               18.0
# H&M               18.0
# HRX               22.0
# Levi's            20.0
# Nike              19.0
# Peter England     22.0
# Puma              18.0
# Reebok            20.0
# Roadster          19.0
# Tommy Hilfiger    18.0
# Under Armour      23.0
# Uniqlo            18.0
# Van Heusen        18.0
# W                 20.0
# Zara              18.0
# Name: Age, dtype: float64

# %%
df.groupby("City")["Age"].max()
# Out:
# City
# Ahmedabad     55.0
# Bengaluru     55.0
# Bhopal        54.0
# Chandigarh    54.0
# Chennai       54.0
# Delhi         55.0
# Hyderabad     54.0
# Indore        55.0
# Jaipur        55.0
# Kolkata       55.0
# Lucknow       55.0
# Mumbai        54.0
# Nagpur        55.0
# Pune          54.0
# Surat         55.0
# Name: Age, dtype: float64
